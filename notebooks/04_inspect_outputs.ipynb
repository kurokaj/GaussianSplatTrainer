# %% [markdown]
# # 04 Inspect Outputs
#
# Load the exported artifacts from a previous run and visualize the prepared images and sparse reconstruction.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
src_path = repo_root / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from pipeline.export import collect_run_artifacts, load_reconstruction_summary
from pipeline.reconstruct import build_run_paths, load_reconstruction_job
from pipeline.viz import show_camera_trajectory, show_image_samples, show_sparse_model

# %%
CONFIG_PATH = repo_root / "configs" / "house_global.yaml"
job = load_reconstruction_job(CONFIG_PATH)
paths = build_run_paths(job.config)

collect_run_artifacts(paths), load_reconstruction_summary(paths).to_dict()

# %%
show_image_samples(paths.prepared_images_dir)
show_sparse_model(paths.sparse_text_dir)
show_camera_trajectory(paths.sparse_text_dir)
