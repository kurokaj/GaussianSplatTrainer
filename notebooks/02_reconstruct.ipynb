# %% [markdown]
# # 02 Reconstruct
#
# Run the COLMAP sparse reconstruction and visualize the exported text model.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
src_path = repo_root / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from pipeline.reconstruct import load_reconstruction_job, run_reconstruction
from pipeline.viz import show_sparse_model

# %%
CONFIG_PATH = repo_root / "configs" / "house_global.yaml"
job = load_reconstruction_job(CONFIG_PATH)
result = run_reconstruction(job)
result.to_dict()

# %%
show_sparse_model(result.sparse_text_path)
